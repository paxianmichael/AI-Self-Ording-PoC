# %% [markdown]
# <a href="https://colab.research.google.com/github/paxianmichael/AI-Self-Ording-PoC/blob/main/evaluation_metrics_gpt_prompt_ans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# !pip install --upgrade openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.8 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import openai
import os
import numpy as np
import pandas as pd
import random
import json
import time

menu_data = """
Items	Price
Chick-fil-A Deluxe Sandwich	4.92
Spicy Chicken Sandwich  4.51
Spicy Deluxe Sandwich 5.29
Grilled Chicken Sandwich	4.72
Chick-fil-A Grilled Chicken Club Sandwich	4.26
Bottled Water	2.29
Fountain Drink	2.19
Coca-Cola	2.99
Sweet Tea	2.19
Lemonade	2.19
Coffee (medium)	2.49
Coffee (small) 2.19
Hot Chocolate 2.49
Chick-fil-A Chicken Sandwich  4.21
Chick-fil-A Nuggets 3.58
Grilled Nuggets 3.42
Chick-fil-A Chick-n-Strips  3.11
Chick-fil-A CoolWrap  3.28
Chick-fil-A Chicken Biscuit 5.89
Chick-fil-A Chicken Mini (4 ct) 6.90
Bacon Biscuit 5.37
Sausage Biscuit 5.37
Chick-fil-A Nuggets (8 ct)  7.89
Chick-fil-A Nuggets (12 ct) 9.55
Grilled Market Salad  9.85
Spicy Southwest Salad 9.85
Cobb Salad  9.85
Waffle Potato FriesTM (medium)  2.18
Waffle Potato FriesTM (large) 2.45
Potato Chips  1.75
Apple Juice 1.70
Milk (white or chocolate) 1.70
Orange Juice  3.05
Iced Coffee (medium)  3.05
Iced Coffee (large) 3.41
Soda/Freshly Brewed Tea (medium)  1.99
Soda/Freshly Brewed Tea (large) 2.39
Freshly Squeezed Lemonade (medium)  2.39
Freshly Squeezed Lemonade (large) 2.77
Chocolate Chunk Cookie  1.55
Ice Dream Cup (small) 2.15
Ice Dream Cup (large) 2.46
Ice Dream Cone (small)  1.64
Ice Dream Cone (large)  2.11
Frosted Lemonade (small) 3.65
Frosted Lemonade (large) 4.30
Strawberry Frosted Lemonade (small) 4.0
Strawberry Frosted Lemonade (large) 4.65
Frosted Coffee (small) 3.65
Frosted Coffee (large)  4.30
Handspun Milkshake (small)  3.65
Handspun Milkshake (large)  4.30

"""

# %%
MODEL = "gpt-3.5-turbo"
openai.api_key = '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'
# i want 3 chick-fil-a chicken biscuits, within these 3 chicken biscuits, One with sausage and another with an extra layer of biscuit

messages = [
    {"role": "system", "content": "You are a Chick-fil-A self-ordering kiosk and your response should always be in JSON format."},
    {"role": "system", "content": "Your JSON object must always contain the following fields:\
    \"message\" which is your actual response message to the customer, \
    \"cart\" which is a list of ordered items, and each item must have \"name\", \"quantity\", \"price\", and \"notes\",\
    \"show\" which can be classified into \"drinks\", \"meals\",\
    \"is_final\" which indicates the end of the conversation"},
    {"role": "system", "content": f"Here is the menu: {menu_data}"}]

while True:
    user_input = input("You: ")
    messages.append({"role": "user", "content": user_input})

    response = openai.ChatCompletion.create(
        model=MODEL,
        messages=messages,
        temperature=0

    )

    print(f"Ordering_AI: {response.choices[0].message.content}")
    messages.append(response.choices[0].message)

    if user_input.strip().lower() == "thank you" or user_input.strip().lower() == "no":
        #store_order.append(response.choices[0].message.content)
        break

# %% [markdown]
# ## chatgpt 3.5 predicted data
#
# #1 F
#
# {
#   "message": "Sure! I have added 3 Spicy Deluxe Sandwiches and 1 Grilled Chicken Club Sandwich to your cart.",
#   "cart": [
#     {
#       "name": "Spicy Deluxe Sandwich",
#       "quantity": 3,
#       "price": 5.29,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Chicken Club Sandwich",
#       "quantity": 1,
#       "price": 4.26,
#       "notes": ""
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #2 F
# {
#   "message": "Sure! I have added 3 Spicy Chicken Sandwiches, 1 Grilled Chicken Sandwich, and 1 Waffle Potato Fries (medium) to your cart.",
#   "cart": [
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 3,
#       "price": 4.51,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.72,
#       "notes": ""
#     },
#     {
#       "name": "Waffle Potato Fries (medium)",
#       "quantity": 1,
#       "price": 2.18,
#       "notes": ""
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #3 T
# {
#   "message": "Sure! I have added your order to the cart.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Deluxe Sandwich",
#       "quantity": 2,
#       "price": 4.92,
#       "notes": "Extra pickles"
#     },
#   {
#       "name": "Cobb Salad",
#       "quantity": 1,
#       "price": 9.85,
#       "notes": ""
#     }，
#     {
#       "name": "Waffle Potato FriesTM (medium)",
#       "quantity": 1,
#       "price": 2.18,
#       "notes": ""
#     },
#
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #4 F
# {
#   "message": "Sure! I have added 3 Chick-fil-A Chicken Biscuits to your cart.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chicken Biscuit",
#       "quantity": 3,
#       "price": 5.89,
#       "notes": ""
#     },
#     {
#       "name": "Sausage Biscuit",
#       "quantity": 1,
#       "price": 5.37,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Chicken Biscuit (Extra Biscuit)",
#       "quantity": 1,
#       "price": 5.89,
#       "notes": "Extra layer of biscuit"
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #5 F
# {
#   "message": "Sure! I have added three Chick-fil-A Chicken Biscuits to your cart.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chicken Biscuit",
#       "quantity": 3,
#       "price": 5.89,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Chicken Biscuit with Sausage",
#       "quantity": 1,
#       "price": 5.89,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Chicken Biscuit with Extra Biscuit",
#       "quantity": 1,
#       "price": 5.89,
#       "notes": "Extra biscuit layer"
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #6 T
# {
#   "message": "Your order has been added to the cart.",
#   "cart": [
#     {
#       "name": "Handspun Milkshake (large)",
#       "quantity": 2,
#       "price": 4.30,
#       "notes": ""
#     },
#     {
#       "name": "Chocolate Chunk Cookie",
#       "quantity": 1,
#       "price": 1.55,
#       "notes": "Crumbled into the chocolate milkshake"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #7 F(double check)
# {
#   "message": "Sure! I have added four Grilled Market Salads to your cart.",
#   "cart": [
#     {
#       "name": "Grilled Market Salad",
#       "quantity": 4,
#       "price": 9.85,
#       "notes": ""
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #8 T
# {
#   "message": "Your order has been placed. Here are the details:",
#   "cart": [
#     {
#       "name": "Grilled Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.72,
#       "notes": "Extra cheese"
#     },
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.51,
#       "notes": "No pickles, extra lettuce"
#     },
#     {
#       "name": "Large Lemonade",
#       "quantity": 2,
#       "price": 2.19,
#       "notes": "1 lemonade with extra ice and less sugar"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #9 F
# {
#   "message": "Sure! Here are your orders:",
#   "cart": [
#     {
#       "name": "Chick-fil-A Nuggets (12 ct)",
#       "quantity": 1,
#       "price": 9.55,
#       "notes": "Substitute with Grilled Nuggets"
#     },
#     {
#       "name": "Chick-fil-A Nuggets (12 ct)",
#       "quantity": 1,
#       "price": 9.55,
#       "notes": "Extra dipping sauces"
#     },
#     {
#       "name": "Chick-fil-A Nuggets (12 ct)",
#       "quantity": 1,
#       "price": 9.55,
#       "notes": "Medium Sweet Tea with light ice"
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #10 T
# {
#   "message": "Your order has been placed successfully!",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chicken Biscuit",
#       "quantity": 2,
#       "price": 5.89,
#       "notes": "Extra butter on one biscuit, substitute chicken with bacon on the other"
#     },
#     {
#       "name": "Freshly Squeezed Lemonade",
#       "quantity": 1,
#       "price": 2.39,
#       "notes": "In place of Coke"
#     }
#   ],
#   "is_final": true
# }
#
# #11 T
# {
#   "message": "Your order has been placed.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Grilled Chicken Club Sandwich",
#       "quantity": 1,
#       "price": 4.26,
#       "notes": "Substitute grilled chicken with Spicy Chicken"
#     },
#     {
#       "name": "Frosted Coffee (large)",
#       "quantity": 1,
#       "price": 4.30,
#       "notes": "Extra whipped cream, drizzle of chocolate syrup"
#     }
#   ],
#   "is_final": true
# }
#
# #12 T
# {
#   "message": "Your order has been received.",
#   "cart": [
#     {
#       "name": "Waffle Potato FriesTM (large)",
#       "quantity": 2,
#       "price": 2.45,
#       "notes": [
#         "Extra salt",
#         "Well done"
#       ]
#     },
#     {
#       "name": "Bottled Water",
#       "quantity": 1,
#       "price": 2.29,
#       "notes": []
#     },
#     {
#       "name": "Fountain Drink (medium)",
#       "quantity": 1,
#       "price": 2.19,
#       "notes": [
#         "No ice"
#       ]
#     }
#   ],
#   "show": "drinks",
#   "is_final": false
# }
#
# #13 F
# {
#   "message": "Your order has been placed.",
#   "cart": [
#     {
#       "name": "Spicy Southwest Salad",
#       "quantity": 2,
#       "price": 9.85,
#       "notes": "Omit corn, add extra black beans"
#     },
#     {
#       "name": "Spicy Southwest Salad",
#       "quantity": 1,
#       "price": 9.85,
#       "notes": "Substitute spicy chicken for grilled chicken"
#     },
#     {
#       "name": "Hot Chocolate",
#       "quantity": 1,
#       "price": 2.49,
#       "notes": "Extra marshmallows on the side"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #14 F
# {
#   "message": "Sure! I have added two Cobb Salads with extra chicken to your order. I have also changed one of the Cobb Salads to a Grilled Market Salad. Lastly, I have added a Chocolate Chunk Cookie to your order.",
#   "cart": [
#     {
#       "name": "Cobb Salad",
#       "quantity": 2,
#       "price": 9.85,
#       "notes": "Extra chicken"
#     },
#     {
#       "name": "Grilled Market Salad",
#       "quantity": 1,
#       "price": 9.85,
#       "notes": ""
#     },
#     {
#       "name": "Chocolate Chunk Cookie",
#       "quantity": 1,
#       "price": 1.55,
#       "notes": ""
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #15 T
# {
#   "message": "Your order has been placed successfully.",
#   "cart": [
#     {
#       "name": "Grilled Nuggets",
#       "quantity": 3,
#       "price": 3.42,
#       "notes": "Extra salt"
#     },
#     {
#       "name": "Waffle Potato FriesTM (medium)",
#       "quantity": 2,
#       "price": 2.18,
#       "notes": ""
#     },
#     {
#       "name": "Iced Coffee (large)",
#       "quantity": 1,
#       "price": 3.41,
#       "notes": "Extra milk, less ice"
#     },
#     {
#       "name": "Sweet Tea",
#       "quantity": 1,
#       "price": 2.19,
#       "notes": ""
#     }
#   ],
#   "show": "drinks",
#   "is_final": true
# }
#
# #16 T
# {
#   "message": "Sure! I have added two Spicy Chicken Sandwiches and two orders of Chick-fil-A Chick-n-Strips to your cart.",
#   "cart": [
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 2,
#       "price": 4.51,
#       "notes": [
#         "Remove sauce, add extra lettuce",
#         "Add bacon"
#       ]
#     },
#     {
#       "name": "Chick-fil-A Chick-n-Strips",
#       "quantity": 2,
#       "price": 3.11,
#       "notes": [
#         "Make one order spicy",
#         "Add honey mustard dipping sauce"
#       ]
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #17 T
# {
#   "message": "Your order has been received.",
#   "cart": [
#     {
#       "name": "Grilled Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.72,
#       "notes": "Lettuce wrap, extra cheese"
#     },
#     {
#       "name": "Chick-fil-A Grilled Chicken Club Sandwich",
#       "quantity": 1,
#       "price": 4.26,
#       "notes": "Spicy Chicken, no bacon"
#     },
#     {
#       "name": "Lemonade",
#       "quantity": 1,
#       "price": 2.19,
#       "notes": "Medium, extra sugar"
#     },
#     {
#       "name": "Coca-Cola",
#       "quantity": 1,
#       "price": 2.99,
#       "notes": "Large, no ice"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #18 F
# {
#   "message": "Sure! I have added the following items to your cart:",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chicken Mini (4 ct)",
#       "quantity": 2,
#       "price": 6.90,
#       "notes": "2 with sausage"
#     },
#     {
#       "name": "Cobb Salad",
#       "quantity": 1,
#       "price": 9.85,
#       "notes": "No tomatoes, extra cheese"
#     },
#     {
#       "name": "Frosted Lemonade (small)",
#       "quantity": 1,
#       "price": 3.65,
#       "notes": "Extra ice"
#     },
#     {
#       "name": "Coffee (medium)",
#       "quantity": 1,
#       "price": 2.49,
#       "notes": "Cream on the side"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #19 F
# {
#   "message": "Sure! I have added your items to the cart.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Nuggets (8 ct)",
#       "quantity": 3,
#       "price": 7.89,
#       "notes": "Extra Chick-fil-A sauce"
#     },
#     {
#       "name": "Waffle Potato FriesTM (large)",
#       "quantity": 2,
#       "price": 2.45,
#       "notes": "Ketchup and mayo"
#     },
#     {
#       "name": "Waffle Potato FriesTM (large)",
#       "quantity": 1,
#       "price": 2.45,
#       "notes": "Ketchup, mayo, and cheese on top"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #20 T
# {
#   "message": "Sure! I have added your items to the cart.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chicken Biscuit",
#       "quantity": 2,
#       "price": 5.89,
#       "notes": "Extra honey and butter, omit chicken"
#     },
#     {
#       "name": "Spicy Deluxe Sandwich",
#       "quantity": 1,
#       "price": 5.29,
#       "notes": "Extra spicy sauce, omit lettuce"
#     },
#     {
#       "name": "Orange Juice",
#       "quantity": 1,
#       "price": 3.05,
#       "notes": "No ice"
#     },
#     {
#       "name": "Milk",
#       "quantity": 1,
#       "price": 1.70,
#       "notes": "Small"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #21 T
# {
#   "message": "Your order has been placed successfully.",
#   "cart": [
#     {
#       "name": "Grilled Chicken Sandwich",
#       "quantity": 2,
#       "price": 4.72,
#       "notes": "No lettuce, double cheese"
#     },
#     {
#       "name": "Coca-Cola",
#       "quantity": 1,
#       "price": 2.99,
#       "notes": "Light ice"
#     },
#     {
#       "name": "Sweet Tea",
#       "quantity": 1,
#       "price": 2.19,
#       "notes": "Light ice"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #22 T
# {
#   "message": "Sure! Your order has been added to the cart.",
#   "cart": [
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.51,
#       "notes": "No pickles, extra spicy sauce"
#     },
#     {
#       "name": "Chick-fil-A Deluxe Sandwich",
#       "quantity": 1,
#       "price": 4.92,
#       "notes": "Extra patty, no cheese"
#     },
#     {
#       "name": "Large Lemonade (extra sugar)",
#       "quantity": 1,
#       "price": 2.77,
#       "notes": "Extra sugar"
#     },
#     {
#       "name": "Large Lemonade (no sugar)",
#       "quantity": 1,
#       "price": 2.77,
#       "notes": "No sugar"
#     }
#   ],
#   "show": "drinks",
#   "is_final": false
# }
#
# #23 T
# {
#   "message": "Your order has been received. Here is the summary:",
#   "cart": [
#     {
#       "name": "Chick-fil-A Nuggets (8 ct)",
#       "quantity": 3,
#       "price": 7.89,
#       "notes": "1st: Extra buffalo sauce, 2nd: Honey mustard, 3rd: No sauce, extra napkins"
#     },
#     {
#       "name": "Coffee (large)",
#       "quantity": 1,
#       "price": 2.49,
#       "notes": "3 sugars"
#     },
#     {
#       "name": "Freshly Squeezed Lemonade (medium)",
#       "quantity": 1,
#       "price": 2.39,
#       "notes": ""
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #24 T
#  {
#   "message": "Your order has been placed successfully.",
#   "cart": [
#     {
#       "name": "Grilled Market Salad",
#       "quantity": 2,
#       "price": 9.85,
#       "notes": "Omit cheese, extra carrots"
#     },
#     {
#       "name": "Waffle Potato FriesTM (medium)",
#       "quantity": 1,
#       "price": 2.18,
#       "notes": "Extra seasoning"
#     },
#     {
#       "name": "Frosted Coffee (small)",
#       "quantity": 1,
#       "price": 3.65,
#       "notes": "Whipped cream on top"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #25 T
# {
#   "message": "Your order has been received.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chicken Biscuit",
#       "quantity": 1,
#       "price": 5.89,
#       "notes": "Extra butter"
#     },
#     {
#       "name": "Bacon Biscuit",
#       "quantity": 1,
#       "price": 5.37,
#       "notes": "Substitute bacon for sausage"
#     },
#     {
#       "name": "Hot Chocolate",
#       "quantity": 1,
#       "price": 2.49,
#       "notes": "Small with whipped cream"
#     },
#     {
#       "name": "Iced Coffee",
#       "quantity": 1,
#       "price": 3.41,
#       "notes": "Large with extra ice"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #26 T
# {
#   "message": "Your order has been received.",
#   "cart": [
#     {
#       "name": "Cobb Salad",
#       "quantity": 2,
#       "price": 9.85,
#       "notes": [
#         "No tomatoes",
#         "Double chicken, no corn"
#       ]
#     },
#     {
#       "name": "Chocolate Chunk Cookie",
#       "quantity": 1,
#       "price": 1.55,
#       "notes": []
#     },
#     {
#       "name": "Ice Dream Cup",
#       "quantity": 1,
#       "price": 2.11,
#       "notes": [
#         "With chocolate syrup"
#       ]
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #27 F
# {
#   "message": "Your order has been updated.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chick-n-Strips",
#       "quantity": 2,
#       "price": 3.11,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Nuggets",
#       "quantity": 1,
#       "price": 3.58,
#       "notes": ""
#     },
#     {
#       "name": "Iced Coffee (large)",
#       "quantity": 1,
#       "price": 3.41,
#       "notes": ""
#     },
#     {
#       "name": "Chocolate Chunk Cookie",
#       "quantity": 1,
#       "price": 1.55,
#       "notes": ""
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #28 F
# {
#   "message": "Your order has been updated.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Nuggets (8 ct)",
#       "quantity": 3,
#       "price": 7.89,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Nuggets",
#       "quantity": 1,
#       "price": 3.42,
#       "notes": ""
#     },
#     {
#       "name": "Sweet Tea",
#       "quantity": 2,
#       "price": 2.19,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Nuggets (12 ct)",
#       "quantity": 1,
#       "price": 9.55,
#       "notes": ""
#     },
#     {
#       "name": "Freshly Squeezed Lemonade (large)",
#       "quantity": 1,
#       "price": 2.77,
#       "notes": ""
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #29 F
# {
#   "message": "Your order has been updated. Here is your updated order:",
#   "cart": [
#     {
#       "name": "Chick-fil-A CoolWrap",
#       "quantity": 1,
#       "price": 3.28,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Chick-n-Strips",
#       "quantity": 3,
#       "price": 3.11,
#       "notes": ""
#     }
#   ],
#   "show": "drinks",
#   "is_final": false
# }
#
#
# #30 F
# {
#   "message": "Your order has been updated.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chick-n-Strips",
#       "quantity": 1,
#       "price": 3.11,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Deluxe Sandwich",
#       "quantity": 1,
#       "price": 4.92,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Nuggets",
#       "quantity": 1,
#       "price": 3.42,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Nuggets",
#       "quantity": 1,
#       "price": 3.42,
#       "notes": ""
#     },
#     {
#       "name": "Waffle Potato FriesTM (large)",
#       "quantity": 1,
#       "price": 2.45,
#       "notes": ""
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
#
# #31 F
#
# {
#   "message": "Sure! I have added the following items to your cart:",
#   "cart": [
#     {
#       "name": "Cobb Salad",
#       "quantity": 2,
#       "price": 9.85,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Market Salad",
#       "quantity": 1,
#       "price": 9.85,
#       "notes": ""
#     },
#     {
#       "name": "Large Coffee",
#       "quantity": 1,
#       "price": 2.49,
#       "notes": ""
#     },
#     {
#       "name": "Ice Dream Cone (small)",
#       "quantity": 1,
#       "price": 1.64,
#       "notes": ""
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #32 F
#
# {
#   "message": "Sure! I have added the following items to your cart:",
#   "cart": [
#     {
#       "name": "Handspun Milkshake (small)",
#       "quantity": 2,
#       "price": 3.65,
#       "notes": ""
#     },
#     {
#       "name": "Handspun Milkshake (large)",
#       "quantity": 1,
#       "price": 4.30,
#       "notes": "Upgrade from small"
#     },
#     {
#       "name": "Potato Chips",
#       "quantity": 1,
#       "price": 1.75,
#       "notes": ""
#     },
#     {
#       "name": "Strawberry Frosted Lemonade (small)",
#       "quantity": 1,
#       "price": 4.0,
#       "notes": ""
#     }
#   ],
#   "show": "drinks",
#   "is_final": false
# }
#
# #33 T
#
#  {
#   "message": "Your order has been updated. Here is your revised order:",
#   "cart": [
#     {
#       "name": "Sausage Biscuit",
#       "quantity": 1,
#       "price": 5.37,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Market Salad",
#       "quantity": 1,
#       "price": 9.85,
#       "notes": ""
#     },
#     {
#       "name": "Hot Chocolate",
#       "quantity": 1,
#       "price": 2.49,
#       "notes": ""
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #34 F
#
# {
#   "message": "Your order has been placed.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Deluxe Sandwich",
#       "quantity": 1,
#       "price": 4.92,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.72,
#       "notes": ""
#     },
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.51,
#       "notes": ""
#     },
#     {
#       "name": "Fountain Drink",
#       "quantity": 0,
#       "price": 2.19,
#       "notes": ""
#     },
#     {
#       "name": "Lemonade",
#       "quantity": 1,
#       "price": 2.19,
#       "notes": ""
#     },
#     {
#       "name": "Waffle Potato FriesTM",
#       "quantity": 1,
#       "price": 2.45,
#       "notes": ""
#     },
#     {
#       "name": "Chocolate Chunk Cookie",
#       "quantity": 2,
#       "price": 1.55,
#       "notes": ""
#     }
#   ],
#   "show": "",
#   "is_final": true
# }
#
# #35 F
#
# {
#   "message": "Your order has been updated. Here is your revised order:",
#   "cart": [
#     {
#       "name": "Grilled Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.72,
#       "notes": ""
#     },
#     {
#       "name": "Spicy Deluxe Sandwich",
#       "quantity": 1,
#       "price": 5.29,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Chicken Mini (4 ct)",
#       "quantity": 0,
#       "price": 6.90,
#       "notes": ""
#     },
#     {
#       "name": "Sausage Biscuit",
#       "quantity": 1,
#       "price": 5.37,
#       "notes": ""
#     },
#     {
#       "name": "Freshly Squeezed Lemonade (large)",
#       "quantity": 1,
#       "price": 2.77,
#       "notes": ""
#     },
#     {
#       "name": "Ice Dream Cup (small)",
#       "quantity": 1,
#       "price": 2.15,
#       "notes": ""
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
#
# #36 F
# {
#   "message": "Sure! I have added your order to the cart.",
#   "cart": [
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 2,
#       "price": 4.51,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Nuggets",
#       "quantity": 1,
#       "price": 3.42,
#       "notes": "Replace chicken on one sandwich"
#     },
#     {
#       "name": "Lettuce Wrap",
#       "quantity": 1,
#       "price": 0,
#       "notes": "No bun, wrap in lettuce"
#     },
#     {
#       "name": "Regular Mayo",
#       "quantity": 1,
#       "price": 0,
#       "notes": "Replace spicy mayo"
#     },
#     {
#       "name": "Medium Iced Coffee",
#       "quantity": 1,
#       "price": 3.05,
#       "notes": "Add a splash of Lemonade"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #37 F
# {
#   "message": "Sure! I have added three Grilled Nuggets to your cart. Please specify any additional notes for each item.",
#   "cart": [
#     {
#       "name": "Grilled Nuggets",
#       "quantity": 3,
#       "price": 3.42,
#       "notes": ""
#     },
#     {
#       "name": "Grilled Nuggets",
#       "quantity": 1,
#       "price": 3.42,
#       "notes": "Extra sauce"
#     },
#     {
#       "name": "Chick-fil-A Chick-n-Strips",
#       "quantity": 1,
#       "price": 3.11,
#       "notes": ""
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #38 F
# {
#   "message": "Sure! I have added your order to the cart.",
#   "cart": [
#     {
#       "name": "Meal Combination",
#       "quantity": 2,
#       "price": 10.74,
#       "notes": "Bacon Biscuit with medium Waffle Potato Fries"
#     },
#     {
#       "name": "Substitution",
#       "quantity": 1,
#       "price": 9.85,
#       "notes": "Spicy Southwest Salad instead of Waffle Potato Fries with extra bacon in the biscuit"
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #39 T
# {
#   "message": "Sure! I have added your order to the cart.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Nuggets (8 ct)",
#       "quantity": 1,
#       "price": 7.89,
#       "notes": "4 spicy, 4 regular"
#     },
#     {
#       "name": "Chick-fil-A Nuggets (8 ct)",
#       "quantity": 1,
#       "price": 7.89,
#       "notes": "Extra pickles"
#     },
#     {
#       "name": "Lemonade",
#       "quantity": 1,
#       "price": 2.19,
#       "notes": "Half Lemonade, half Iced Tea"
#     },
#     {
#       "name": "Chocolate Chunk Cookie",
#       "quantity": 1,
#       "price": 1.55,
#       "notes": "Warmed"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #40 F
# {
#   "message": "Your order has been received.",
#   "cart": [
#     {
#       "name": "Meal Deal",
#       "quantity": 2,
#       "price": 6.28,
#       "notes": "One with Sweet Tea, extra lettuce"
#     }
#   ],
#   "show": "is_final",
#   "is_final": true
# }
#
# #41 F
# {
#   "message": "Sure! I have added four Chick-fil-A Chicken Minis to your cart. Two of them will have nuggets instead of chicken. I have also added a medium Fountain Drink and a small Ice Dream Cone to your order.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Chicken Mini (4 ct)",
#       "quantity": 4,
#       "price": 6.90,
#       "notes": ""
#     },
#     {
#       "name": "Chick-fil-A Nuggets (4 ct)",
#       "quantity": 2,
#       "price": 3.58,
#       "notes": "Replace chicken with nuggets"
#     },
#     {
#       "name": "Fountain Drink",
#       "quantity": 1,
#       "price": 2.19,
#       "notes": "Medium"
#     },
#     {
#       "name": "Ice Dream Cone",
#       "quantity": 1,
#       "price": 1.64,
#       "notes": "Small"
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #42 T
# {
#   "message": "Your order has been updated. You have added 2 Spicy Chicken Sandwiches and a Lemonade.",
#   "cart": [
#     {
#       "name": "Chick-fil-A Deluxe Sandwich",
#       "quantity": 2,
#       "price": 4.92,
#       "notes": ""
#     },
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 2,
#       "price": 4.51,
#       "notes": ""
#     },
#     {
#       "name": "Lemonade",
#       "quantity": 1,
#       "price": 2.19,
#       "notes": ""
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #43 F
# {
#   "message": "Your order has been placed.",
#   "cart": [
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 5,
#       "price": 4.51,
#       "notes": "No spices, extra pickles"
#     },
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 5,
#       "price": 4.51,
#       "notes": "Double spices, no pickles"
#     },
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 5,
#       "price": 4.51,
#       "notes": "Extra layer of bread"
#     },
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 5,
#       "price": 4.51,
#       "notes": "Replace chicken with nuggets"
#     },
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 5,
#       "price": 4.51,
#       "notes": "Plain with triple lettuce"
#     }
#   ],
#   "show": "meals",
#   "is_final": true
# }
#
# #44 F
# {
#   "message": "Sure! I have added your order to the cart.",
#   "cart": [
#     {
#       "name": "Meal Package",
#       "quantity": 2,
#       "price": 9.9,
#       "notes": "Grilled Chicken Sandwich with medium Waffle Potato Fries"
#     },
#     {
#       "name": "Spicy Southwest Salad",
#       "quantity": 1,
#       "price": 9.85,
#       "notes": "Replace fries with Spicy Southwest Salad"
#     }
#   ],
#   "show": "meals",
#   "is_final": false
# }
#
# #45 T
# {
#   "message": "Your order has been placed.",
#   "cart": [
#     {
#       "name": "Grilled Chicken Club Sandwich",
#       "quantity": 1,
#       "price": 4.26,
#       "notes": "Double chicken"
#     },
#     {
#       "name": "Spicy Chicken Sandwich",
#       "quantity": 1,
#       "price": 4.51,
#       "notes": "No lettuce"
#     },
#     {
#       "name": "Waffle Potato Fries (medium)",
#       "quantity": 1,
#       "price": 2.18,
#       "notes": ""
#     },
#     {
#       "name": "Fountain Drink (medium)",
#       "quantity": 2,
#       "price": 2.19,
#       "notes": ""
#     }
#   ],
#   "show": "",
#   "is_final": true
# }

# %%
curr_prompt = ["F","F","T","F","F","T","F","T","F","T","T","T","F","F","T","T","T","F","F","T","T","T","T","T","T","T","F","F","F","F","F","F","T","F","F","F","F","F","T","F","F","T","F","F","T"]
print(len(curr_prompt))
number_of_T = curr_prompt.count("T")
total_length = len(curr_prompt)

print(number_of_T/total_length)
# Out:
# 45
# 0.4444444444444444
